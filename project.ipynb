# %% [markdown]
# # importing os

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HI'

# %% [markdown]
# # changing the current directory

# %%
os.chdir("C:/Users/HI/Desktop/project")
os.getcwd()
# Out:
# 'C:\\Users\\HI\\Desktop\\project'

# %% [markdown]
# # fetching the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
car_prices=pd.read_csv("7CarPrice_Assignment.csv")
car_prices
# Out:
#      car_ID  symboling                       CarName fueltype aspiration  \
# 0         1          3            alfa-romero giulia      gas        std
# 1         2          3           alfa-romero stelvio      gas        std
# 2         3          1      alfa-romero Quadrifoglio      gas        std
# 3         4          2                   audi 100 ls      gas        std
# 4         5          2                    audi 100ls      gas        std
# 5         6          2                      audi fox      gas        std
# 6         7          1                    audi 100ls      gas        std
# 7         8          1                     audi 5000      gas        std
# 8         9          1                     audi 4000      gas      turbo
# 9        10          0           audi 5000s (diesel)      gas      turbo
# 10       11          2                      bmw 320i      gas        std
# 11       12          0                      bmw 320i      gas        std
# ...

# %% [markdown]
# # droping car_ID feature

# %%
car_prices=car_prices.drop(['car_ID','CarName'],axis=1)
car_prices
# Out:
#      symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0            3      gas        std        two  convertible        rwd
# 1            3      gas        std        two  convertible        rwd
# 2            1      gas        std        two    hatchback        rwd
# 3            2      gas        std       four        sedan        fwd
# 4            2      gas        std       four        sedan        4wd
# 5            2      gas        std        two        sedan        fwd
# 6            1      gas        std       four        sedan        fwd
# 7            1      gas        std       four        wagon        fwd
# 8            1      gas      turbo       four        sedan        fwd
# 9            0      gas      turbo        two    hatchback        4wd
# 10           2      gas        std        two        sedan        rwd
# 11           0      gas        std       four        sedan        rwd
# ...

# %% [markdown]
# #since the car_ID feature is unnecessery,we are droping the feature

# %% [markdown]
# # identifying null values

# %%
car_prices.apply(lambda x:sum(x.isnull()),axis = 0)
# Out:
# symboling           0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# #here the data doesnt have any null values , so it not necessary to clean the data

# %% [markdown]
# # datatype of each feature

# %%
car_prices.dtypes
# Out:
# symboling             int64
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# #here the output is price,since the datatype of price is numerical,we have to use linear regression.

# %% [markdown]
# # describe

# %%
car_prices.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %% [markdown]
# #since some features have outliers,we have to normalise the data

# %% [markdown]
# # covariance

# %%
car_prices.cov()
# Out:
#                    symboling     wheelbase     carlength      carwidth  \
# symboling           1.550789     -3.989099     -5.494240     -0.622229
# wheelbase          -3.989099     36.261782     64.975189     10.271615
# carlength          -5.494240     64.975189    152.208688     22.261035
# carwidth           -0.622229     10.271615     22.261035      4.601900
# carheight          -1.646344      8.673144     14.802788      1.463579
# curbweight       -147.636083   2434.296746   5638.336200    968.445072
# enginesize         -5.486035    142.766545    351.081549     65.697786
# boreratio          -0.043864      0.797132      2.026453      0.324874
# stroke             -0.003411      0.303957      0.501153      0.123070
# compressionratio   -0.883009      5.974562      7.762938      1.543367
# horsepower          3.490100     84.128637    269.606949     54.353494
# peakrpm           162.520325  -1035.374582  -1690.336920   -225.123505
# ...

# %% [markdown]
# # correlation

# %%
car_prices.corr()
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %% [markdown]
# # Box Plot

# %%
car_prices.boxplot(column='price',by='wheelbase')

# %%
car_prices.boxplot(column='price',by='carlength')

# %%
car_prices.boxplot(column='price',by='carwidth')

# %%
car_prices.boxplot(column='price',by='curbweight')

# %%
car_prices.boxplot(column='price',by='enginesize')

# %%
car_prices.boxplot(column='price',by='boreratio')

# %%
car_prices.boxplot(column='price',by='horsepower')

# %%
car_prices.dtypes
# Out:
# symboling             int64
# fueltype              int32
# aspiration            int32
# doornumber            int32
# carbody               int32
# drivewheel            int32
# enginelocation        int32
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype            int32
# cylindernumber        int32
# enginesize            int64
# fuelsystem            int32
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# # Pair Plot

# %%
import seaborn as sns
sns.pairplot(car_prices)

# %% [markdown]
# # Dist Plot

# %%
sns.distplot(car_prices['wheelbase'])
# Out:
# C:\Users\HI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(car_prices['carlength'])
# Out:
# C:\Users\HI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(car_prices['carwidth'])
# Out:
# C:\Users\HI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(car_prices['curbweight'])
# Out:
# C:\Users\HI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(car_prices['boreratio'])
# Out:
# C:\Users\HI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(car_prices['horsepower'])
# Out:
# C:\Users\HI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(car_prices['enginesize'])
# Out:
# C:\Users\HI\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
corr=car_prices.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
wheelbase=car_prices['wheelbase']

# %%
carlength=car_prices['carlength']

# %%
carwidth=car_prices['carwidth']

# %%
carheight=car_prices['carheight']

# %%
curbweight=car_prices['curbweight']

# %%
enginesize=car_prices['enginesize']

# %%
boreratio=car_prices['boreratio']

# %%
horsepower=car_prices['horsepower']

# %%
price=car_prices['price']

# %%
ax=plt.plot(carlength,price,'o')
plt.ylabel('price')
plt.xlabel('carlength')
# Out:
# Text(0.5,0,'carlength')

# %%
ax=plt.plot(wheelbase,price,'o')
plt.ylabel('price')
plt.xlabel('wheelbase')
# Out:
# Text(0.5,0,'wheelbase')

# %%
ax=plt.plot(carwidth,price,'o')
plt.ylabel('price')
plt.xlabel('carwidth')
# Out:
# Text(0.5,0,'carwidth')

# %%
ax=plt.plot(curbweight,price,'o')
plt.ylabel('price')
plt.xlabel('curbweight')
# Out:
# Text(0.5,0,'curbweight')

# %%
ax=plt.plot(enginesize,price,'o')
plt.ylabel('price')
plt.xlabel('enginesize')
# Out:
# Text(0.5,0,'enginesize')

# %%
ax=plt.plot(boreratio,price,'o')
plt.ylabel('price')
plt.xlabel('boreratio')
# Out:
# Text(0.5,0,'boreratio')

# %%
ax=plt.plot(horsepower,price,'o')
plt.ylabel('price')
plt.xlabel('horsepower')
# Out:
# Text(0.5,0,'horsepower')

# %%
import statsmodels.api as sm
model=sm.OLS(price,wheelbase).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     659.1
# Date:                Fri, 24 May 2019   Prob (F-statistic):           8.07e-66
# Time:                        12:29:46   Log-Likelihood:                -2120.8
# No. Observations:                 205   AIC:                             4244.
# Df Residuals:                     204   BIC:                             4247.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# wheelbase    136.7689      5.327     25.674      0.000     126.265     147.272
# ...

# %%
model=sm.OLS(price,carlength).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     700.6
# Date:                Fri, 24 May 2019   Prob (F-statistic):           6.66e-68
# Time:                        12:29:46   Log-Likelihood:                -2116.0
# No. Observations:                 205   AIC:                             4234.
# Df Residuals:                     204   BIC:                             4237.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# carlength     78.1019      2.951     26.469      0.000      72.284      83.920
# ...

# %%
model=sm.OLS(price,carwidth).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     632.9
# Date:                Fri, 24 May 2019   Prob (F-statistic):           1.88e-64
# Time:                        12:29:46   Log-Likelihood:                -2124.0
# No. Observations:                 205   AIC:                             4250.
# Df Residuals:                     204   BIC:                             4253.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# carwidth     204.2095      8.117     25.158      0.000     188.206     220.214
# ...

# %%
model=sm.OLS(price,enginesize).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     2105.
# Date:                Fri, 24 May 2019   Prob (F-statistic):          1.88e-109
# Time:                        12:29:46   Log-Likelihood:                -2019.9
# No. Observations:                 205   AIC:                             4042.
# Df Residuals:                     204   BIC:                             4045.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# enginesize   110.7222      2.413     45.883      0.000     105.964     115.480
# ...

# %%
model=sm.OLS(price,boreratio).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     683.8
# Date:                Fri, 24 May 2019   Prob (F-statistic):           4.56e-67
# Time:                        12:29:47   Log-Likelihood:                -2117.9
# No. Observations:                 205   AIC:                             4238.
# Df Residuals:                     204   BIC:                             4241.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# boreratio   4067.9365    155.569     26.149      0.000    3761.207    4374.666
# ...

# %%
model=sm.OLS(price,horsepower).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     1854.
# Date:                Fri, 24 May 2019   Prob (F-statistic):          2.43e-104
# Time:                        12:29:47   Log-Likelihood:                -2031.7
# No. Observations:                 205   AIC:                             4065.
# Df Residuals:                     204   BIC:                             4069.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# horsepower   132.0043      3.066     43.055      0.000     125.959     138.049
# ...

# %%
model=sm.OLS(price,curbweight).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     1224.
# Date:                Fri, 24 May 2019   Prob (F-statistic):           3.69e-88
# Time:                        12:29:47   Log-Likelihood:                -2069.2
# No. Observations:                 205   AIC:                             4140.
# Df Residuals:                     204   BIC:                             4144.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# curbweight     5.4975      0.157     34.992      0.000       5.188       5.807
# ...

# %% [markdown]
# # linear regression  (60-20)

# %% [markdown]
# # wheelbase-price

# %%
#split the data into training set and test set
from sklearn.model_selection import train_test_split

# %%
X=car_prices['wheelbase']
y=car_prices['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
# 89      94.5
# 171     98.4
# 123    103.3
# 12     101.2
# 127     89.5
# 102    100.4
# 196    104.3
# 159     95.7
# 99      97.2
# 81      96.3
# 188     97.3
# 194    104.3
# 13     101.2
# 82      95.9
# 179    102.9
# 183     97.3
# 45      94.5
# 108    107.9
# 36      96.5
# 166     94.5
# 191    100.4
# 158     95.7
# 112    107.9
# 153     95.7
# 202    109.1
# 118     93.7
# 198    104.3
# 75     102.7
# 21      93.7
# 91      94.5
#        ...
# 22      93.7
# 61      98.8
# 63      98.8
# 7      105.8
# 201    109.1
# 141     97.2
# 86      96.3
# 96      94.5
# 68     110.0
# 50      93.1
# 142     97.2
# 157     95.7
# 156     95.7
# 139     93.7
# 146     97.0
# 101    100.4
# 20      94.5
# 178    102.9
# 25      93.7
# 134     99.1
# 71     115.6
# 129     98.4
# 144     97.0
# 192    100.4
# 79      93.0
# 133     99.1
# 137     99.1
# 72      96.6
# 140     93.3
# 37      96.5
# Name: wheelbase, Length: 123, dtype: float64

# %%
X_test
# Out:
# 78      93.7
# 97      94.5
# 151     95.7
# 44      94.5
# 40      96.5
# 67     110.0
# 98      95.1
# 18      88.4
# 152     95.7
# 62      98.8
# 4       99.4
# 172     98.4
# 197    104.3
# 38      96.5
# 29      95.9
# 170     98.4
# 190     94.5
# 33      93.7
# 136     99.1
# 145     97.0
# 173    102.4
# 31      86.6
# 11     101.2
# 119     93.7
# 169     98.4
# 34      93.7
# 84      95.9
# 184     97.3
# 120     93.7
# 35      96.5
#        ...
# 14     103.5
# 162     95.7
# 59      98.8
# 19      94.5
# 177    102.4
# 39      96.5
# 110    114.2
# 164     94.5
# 56      95.3
# 176    102.4
# 124     95.9
# 181    104.5
# 154     95.7
# 53      93.1
# 94      94.5
# 143     97.2
# 105     91.3
# 132     99.1
# 42      96.5
# 17     110.0
# 5       99.8
# 150     95.7
# 199    104.3
# 48     113.0
# 165     94.5
# 66     104.9
# 114    114.2
# 54      93.1
# 93      94.5
# 122     93.7
# Name: wheelbase, Length: 82, dtype: float64

# %%
y_train
# Out:
# 89      5499.0
# 171    11549.0
# 123     8921.0
# 12     20970.0
# 127    34028.0
# 102    14399.0
# 196    15985.0
# 159     7788.0
# 99      8949.0
# 81      8499.0
# 188     9995.0
# 194    12940.0
# 13     21105.0
# 82     12629.0
# 179    15998.0
# 183     7975.0
# 45      8916.5
# 108    13200.0
# 36      7295.0
# 166     9538.0
# 191    13295.0
# 158     7898.0
# 112    16900.0
# 153     6918.0
# 202    21485.0
# 118     5572.0
# 198    18420.0
# 75     16503.0
# 21      5572.0
# 91      6649.0
#         ...
# 22      6377.0
# 61     10595.0
# 63     10795.0
# 7      18920.0
# 201    19045.0
# 141     7126.0
# 86      8189.0
# 96      7499.0
# 68     28248.0
# 50      5195.0
# 142     7775.0
# 157     7198.0
# 156     6938.0
# 139     7053.0
# 146     7463.0
# 101    13499.0
# 20      6575.0
# 178    16558.0
# 25      6692.0
# 134    15040.0
# 71     34184.0
# 129    31400.5
# 144     9233.0
# 192    13845.0
# 79      7689.0
# 133    12170.0
# 137    18620.0
# 72     35056.0
# ...

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
#         ...
# 14     24565.0
# 162     9258.0
# 59      8845.0
# 19      6295.0
# 177    11248.0
# 39      8845.0
# 110    13860.0
# 164     8238.0
# 56     11845.0
# 176    10898.0
# 124    12764.0
# 181    15750.0
# 154     7898.0
# 53      6695.0
# 94      7299.0
# 143     9960.0
# 105    19699.0
# 132    11850.0
# 42     10345.0
# 17     36880.0
# 5      15250.0
# 150     5348.0
# 199    18950.0
# 48     35550.0
# 165     9298.0
# 66     18344.0
# 114    17075.0
# 54      7395.0
# ...

# %%
X_train=X_train.values.reshape((-1,1))

# %%
X_train
# Out:
# array([[ 94.5],
#        [ 98.4],
#        [103.3],
#        [101.2],
#        [ 89.5],
#        [100.4],
#        [104.3],
#        [ 95.7],
#        [ 97.2],
#        [ 96.3],
#        [ 97.3],
#        [104.3],
#        [101.2],
#        [ 95.9],
#        [102.9],
#        [ 97.3],
#        [ 94.5],
#        [107.9],
#        [ 96.5],
#        [ 94.5],
#        [100.4],
#        [ 95.7],
#        [107.9],
#        [ 95.7],
#        [109.1],
#        [ 93.7],
#        [104.3],
#        [102.7],
#        [ 93.7],
#        [ 94.5],
#        [ 97.3],
#        [ 94.5],
#        [115.6],
#        [ 96.3],
#        [ 95.7],
#        [105.8],
#        [ 98.4],
#        [ 88.6],
#        [ 95.7],
#        [ 93.7],
#        [114.2],
#        [104.9],
#        [ 95.3],
#        [109.1],
#        [ 96.3],
#        [ 94.5],
#        [ 96. ],
#        [112. ],
#        [ 94.5],
#        [ 96.9],
#        [ 96.3],
#        [109.1],
#        [101.2],
#        [ 93.7],
#        [ 95.9],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy=model.score(X_train,y_train)
print("Accuracy of the model:",accuracy)
# Out:
# Accuracy of the model: 0.2004368472943684

# %%
#print coefficients
print("intercept:",model.intercept_)
print("slope:",model.coef_)
# Out:
# intercept: -47039.012965974245
# slope: [613.39681937]

# %%
X_test=X_test.values.reshape((-1,1))

# %%
X_test
# Out:
# array([[ 93.7],
#        [ 94.5],
#        [ 95.7],
#        [ 94.5],
#        [ 96.5],
#        [110. ],
#        [ 95.1],
#        [ 88.4],
#        [ 95.7],
#        [ 98.8],
#        [ 99.4],
#        [ 98.4],
#        [104.3],
#        [ 96.5],
#        [ 95.9],
#        [ 98.4],
#        [ 94.5],
#        [ 93.7],
#        [ 99.1],
#        [ 97. ],
#        [102.4],
#        [ 86.6],
#        [101.2],
#        [ 93.7],
#        [ 98.4],
#        [ 93.7],
#        [ 95.9],
#        [ 97.3],
#        [ 93.7],
#        [ 96.5],
#        [ 94.5],
#        [103.3],
#        [103.5],
#        [ 96.1],
#        [107.9],
#        [ 97.3],
#        [ 93.7],
#        [113. ],
#        [ 95.3],
#        [109.1],
#        [ 93.7],
#        [ 99.2],
#        [ 94.5],
#        [ 97. ],
#        [ 97.3],
#        [ 94.5],
#        [120.9],
#        [ 93.1],
#        [108. ],
#        [100.4],
#        [106.7],
#        [107.9],
#        [103.5],
#        [ 95.7],
#        [ 98.8],
# ...

# %%
#predictions from the model
predictions=model.predict(X_test)
print("predicted price:",predictions,sep = '\n')
# Out:
# predicted price:
# [10436.26900924 10926.98646474 11663.06264799 10926.98646474
#  12153.78010349 20434.63716502 11295.02455636  7185.26586657
#  11663.06264799 13564.59278804 13932.63087967 13319.23406029
#  16938.27529459 12153.78010349 11785.74201186 13319.23406029
#  10926.98646474 10436.26900924 13748.61183386 12460.47851317
#  15772.82133778  6081.1515917  15036.74515454 10436.26900924
#  13319.23406029 10436.26900924 11785.74201186 12644.49755898
#  10436.26900924 12153.78010349 10926.98646474 16324.87847522
#  16447.55783909 11908.42137574 19146.50384433 12644.49755898
#  10436.26900924 22274.82762313 11417.70392024 19882.58002758
#  10436.26900924 13809.95151579 10926.98646474 12460.47851317
#  12644.49755898 10926.98646474 27120.66249618 10068.23091762
#  19207.84352627 14546.02769904 18410.42766109 19146.50384433
#  16447.55783909 11663.06264799 13564.59278804 10926.98646474
#  15772.82133778 12153.78010349 23010.90380638 10926.98646474
# ...

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train = X_train.reshape(-1,1)
y_train_prediction = model.predict(X_train)
X_test = X_test.reshape(-1,1)
y_test_prediction = model.predict(X_test)

# %%
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training = r2_score(y_train,y_train_prediction)
print('The model performance for training set')
print('-------------------------------------')
print('RMSE is {}'.format(rmse_training))
print('R2_score is {}'.format(r2_training))
# Out:
# The model performance for training set
# -------------------------------------
# RMSE is 7101.298198138874
# R2_score is 0.2004368472943684

# %%
rmse_testing = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing = r2_score(y_test,y_test_prediction)
print('The model performance for testing set')
print('-------------------------------------')
print('root mean squared error is:',rmse_testing)
print('r2 score is:',r2_testing)
# Out:
# The model performance for testing set
# -------------------------------------
# root mean squared error is: 5271.353793738008
# r2 score is: 0.4943238555101528

# %%
# plotting values
#data points
plt.scatter(X,y)
plt.xlabel('wheelbase')
plt.ylabel('price')
# Out:
# Text(0,0.5,'price')

# %%
X = X.values.reshape(-1,1)
y_predicted = model.predict(X)
#predicted values
plt.plot(X,y_predicted,color = 'r')
plt.show()

# %% [markdown]
# # carlength-price

# %%
X=car_prices['carlength']
y=car_prices['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
# 89     165.3
# 171    176.2
# 123    174.6
# 12     176.8
# 127    168.9
# 102    184.6
# 196    188.8
# 159    166.3
# 99     173.4
# 81     173.0
# 188    171.7
# 194    188.8
# 13     176.8
# 82     173.2
# 179    183.5
# 183    171.7
# 45     155.9
# 108    186.7
# 36     157.1
# 166    168.7
# 191    180.2
# 158    166.3
# 112    186.7
# 153    169.7
# 202    188.8
# 118    157.3
# 198    188.8
# 75     178.4
# 21     157.3
# 91     165.3
#        ...
# 22     157.3
# 61     177.8
# 63     177.8
# 7      192.7
# 201    188.8
# 141    172.0
# 86     172.4
# 96     165.3
# 68     190.9
# 50     159.1
# 142    172.0
# 157    166.3
# 156    166.3
# 139    157.9
# 146    173.5
# 101    181.7
# 20     158.8
# 178    183.5
# 25     157.3
# 134    186.6
# 71     202.6
# 129    175.7
# 144    172.0
# 192    180.2
# 79     157.3
# 133    186.6
# 137    186.6
# 72     180.3
# 140    157.3
# 37     167.5
# Name: carlength, Length: 123, dtype: float64

# %%
X_test
# Out:
# 78     157.3
# 97     170.2
# 151    158.7
# 44     155.9
# 40     175.4
# 67     190.9
# 98     162.4
# 18     141.1
# 152    158.7
# 62     177.8
# 4      176.6
# 172    176.2
# 197    188.8
# 38     167.5
# 29     173.2
# 170    176.2
# 190    165.7
# 33     150.0
# 136    186.6
# 145    172.0
# 173    175.6
# 31     144.6
# 11     176.8
# 119    157.3
# 169    176.2
# 34     150.0
# 84     173.2
# 184    171.7
# 120    157.3
# 35     163.4
#        ...
# 14     189.0
# 162    166.3
# 59     177.8
# 19     155.9
# 177    175.6
# 39     175.4
# 110    198.9
# 164    168.7
# 56     169.0
# 176    175.6
# 124    173.2
# 181    187.8
# 154    169.7
# 53     166.8
# 94     165.3
# 143    172.0
# 105    170.7
# 132    186.6
# 42     169.1
# 17     197.0
# 5      177.3
# 150    158.7
# 199    188.8
# 48     199.6
# 165    168.7
# 66     175.0
# 114    198.9
# 54     166.8
# 93     170.2
# 122    167.3
# Name: carlength, Length: 82, dtype: float64

# %%
y_train
# Out:
# 89      5499.0
# 171    11549.0
# 123     8921.0
# 12     20970.0
# 127    34028.0
# 102    14399.0
# 196    15985.0
# 159     7788.0
# 99      8949.0
# 81      8499.0
# 188     9995.0
# 194    12940.0
# 13     21105.0
# 82     12629.0
# 179    15998.0
# 183     7975.0
# 45      8916.5
# 108    13200.0
# 36      7295.0
# 166     9538.0
# 191    13295.0
# 158     7898.0
# 112    16900.0
# 153     6918.0
# 202    21485.0
# 118     5572.0
# 198    18420.0
# 75     16503.0
# 21      5572.0
# 91      6649.0
#         ...
# 22      6377.0
# 61     10595.0
# 63     10795.0
# 7      18920.0
# 201    19045.0
# 141     7126.0
# 86      8189.0
# 96      7499.0
# 68     28248.0
# 50      5195.0
# 142     7775.0
# 157     7198.0
# 156     6938.0
# 139     7053.0
# 146     7463.0
# 101    13499.0
# 20      6575.0
# 178    16558.0
# 25      6692.0
# 134    15040.0
# 71     34184.0
# 129    31400.5
# 144     9233.0
# 192    13845.0
# 79      7689.0
# 133    12170.0
# 137    18620.0
# 72     35056.0
# ...

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
#         ...
# 14     24565.0
# 162     9258.0
# 59      8845.0
# 19      6295.0
# 177    11248.0
# 39      8845.0
# 110    13860.0
# 164     8238.0
# 56     11845.0
# 176    10898.0
# 124    12764.0
# 181    15750.0
# 154     7898.0
# 53      6695.0
# 94      7299.0
# 143     9960.0
# 105    19699.0
# 132    11850.0
# 42     10345.0
# 17     36880.0
# 5      15250.0
# 150     5348.0
# 199    18950.0
# 48     35550.0
# 165     9298.0
# 66     18344.0
# 114    17075.0
# 54      7395.0
# ...

# %%
X_train=X_train.values.reshape((-1,1))

# %%
X_train
# Out:
# array([[165.3],
#        [176.2],
#        [174.6],
#        [176.8],
#        [168.9],
#        [184.6],
#        [188.8],
#        [166.3],
#        [173.4],
#        [173. ],
#        [171.7],
#        [188.8],
#        [176.8],
#        [173.2],
#        [183.5],
#        [171.7],
#        [155.9],
#        [186.7],
#        [157.1],
#        [168.7],
#        [180.2],
#        [166.3],
#        [186.7],
#        [169.7],
#        [188.8],
#        [157.3],
#        [188.8],
#        [178.4],
#        [157.3],
#        [165.3],
#        [171.7],
#        [171.2],
#        [202.6],
#        [172.4],
#        [169.7],
#        [192.7],
#        [176.2],
#        [168.8],
#        [166.3],
#        [157.3],
#        [198.9],
#        [175. ],
#        [169. ],
#        [188.8],
#        [172.4],
#        [159.3],
#        [172.6],
#        [199.2],
#        [165.3],
#        [173.6],
#        [172.4],
#        [188.8],
#        [176.8],
#        [150. ],
#        [173.2],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy=model.score(X_train,y_train)
print("Accuracy of the model:",accuracy)
# Out:
# Accuracy of the model: 0.3686933793804503

# %%
#print coefficients
print("intercept:",model.intercept_)
print("slope:",model.coef_)
# Out:
# intercept: -58785.666922060715
# slope: [414.28903941]

# %%
X_test=X_test.values.reshape((-1,1))

# %%
X_test
# Out:
# array([[157.3],
#        [170.2],
#        [158.7],
#        [155.9],
#        [175.4],
#        [190.9],
#        [162.4],
#        [141.1],
#        [158.7],
#        [177.8],
#        [176.6],
#        [176.2],
#        [188.8],
#        [167.5],
#        [173.2],
#        [176.2],
#        [165.7],
#        [150. ],
#        [186.6],
#        [172. ],
#        [175.6],
#        [144.6],
#        [176.8],
#        [157.3],
#        [176.2],
#        [150. ],
#        [173.2],
#        [171.7],
#        [157.3],
#        [163.4],
#        [168.7],
#        [174.6],
#        [193.8],
#        [181.5],
#        [186.7],
#        [171.7],
#        [157.3],
#        [199.6],
#        [169. ],
#        [188.8],
#        [156.9],
#        [178.5],
#        [165.3],
#        [173.5],
#        [171.7],
#        [165.6],
#        [208.1],
#        [159.1],
#        [186.7],
#        [184.6],
#        [187.5],
#        [186.7],
#        [189. ],
#        [166.3],
#        [177.8],
# ...

# %%
#predictions from the model
predictions=model.predict(X_test)
print("predicted price:",predictions,sep = '\n')
# Out:
# predicted price:
# [ 6381.9989776  11726.32758603  6962.00363278  5801.99432242
#  13880.63059098 20302.11070188  8494.87307861  -329.48346089
#   6962.00363278 14874.92428557 14377.77743827 14212.06182251
#  19432.10371911 10607.74717961 12969.19470427 14212.06182251
#   9862.02690867  3357.68898989 18520.6678324  12472.04785697
#  13963.48839886  1120.52817706 14460.63524615  6381.9989776
#  14212.06182251  3357.68898989 12969.19470427 12347.76114515
#   6381.9989776   8909.16211802 11104.89402691 13549.19935945
#  21503.54891618 16407.7937314  18562.09673634 12347.76114515
#   6381.9989776  23906.42534477 11229.18073873 19432.10371911
#   6216.28336184 15164.92661316  9696.31129291 13093.48141609
#  12347.76114515  9820.59800473 27427.88217978  7127.71924855
#  18562.09673634 17692.08975358 18893.52796787 18562.09673634
#  19514.96152699 10110.60033232 14874.92428557  5801.99432242
#  13963.48839886 13880.63059098 23616.42301718 11104.89402691
# ...

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train = X_train.reshape(-1,1)
y_train_prediction = model.predict(X_train)
X_test = X_test.reshape(-1,1)
y_test_prediction = model.predict(X_test)

# %%
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training = r2_score(y_train,y_train_prediction)
print('The model performance for training set')
print('-------------------------------------')
print('RMSE is {}'.format(rmse_training))
print('R2_score is {}'.format(r2_training))
# Out:
# The model performance for training set
# -------------------------------------
# RMSE is 6310.031626964817
# R2_score is 0.3686933793804503

# %%
rmse_testing = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing = r2_score(y_test,y_test_prediction)
print('The model performance for testing set')
print('-------------------------------------')
print('root mean squared error is:',rmse_testing)
print('r2 score is:',r2_testing)
# Out:
# The model performance for testing set
# -------------------------------------
# root mean squared error is: 5030.07244503043
# r2 score is: 0.6047634551004106

# %%
# plotting values
#data points
plt.scatter(X,y)
plt.xlabel('carlength')
plt.ylabel('price')
# Out:
# Text(0,0.5,'price')

# %%
X = X.values.reshape(-1,1)
y_predicted = model.predict(X)
#predicted values
plt.plot(X,y_predicted,color = 'r')
plt.show()

# %% [markdown]
# # carwidth-price

# %%
X=car_prices['carwidth']
y=car_prices['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
# 89     63.8
# 171    65.6
# 123    64.6
# 12     64.8
# 127    65.0
# 102    66.5
# 196    67.2
# 159    64.4
# 99     65.2
# 81     65.4
# 188    65.5
# 194    67.2
# 13     64.8
# 82     66.3
# 179    67.7
# 183    65.5
# 45     63.6
# 108    68.4
# 36     63.9
# 166    64.0
# 191    66.9
# 158    64.4
# 112    68.4
# 153    63.6
# 202    68.9
# 118    63.8
# 198    67.2
# 75     68.0
# 21     63.8
# 91     63.8
#        ...
# 22     63.8
# 61     66.5
# 63     66.5
# 7      71.4
# 201    68.8
# 141    65.4
# 86     65.4
# 96     63.8
# 68     70.3
# 50     64.2
# 142    65.4
# 157    64.4
# 156    64.4
# 139    63.6
# 146    65.4
# 101    66.5
# 20     63.6
# 178    67.7
# 25     63.8
# 134    66.5
# 71     71.7
# 129    72.3
# 144    65.4
# 192    66.9
# 79     63.8
# 133    66.5
# 137    66.5
# 72     70.5
# 140    63.8
# 37     65.2
# Name: carwidth, Length: 123, dtype: float64

# %%
X_test
# Out:
# 78     64.4
# 97     63.8
# 151    63.6
# 44     63.6
# 40     62.5
# 67     70.3
# 98     63.8
# 18     60.3
# 152    63.6
# 62     66.5
# 4      66.4
# 172    65.6
# 197    67.2
# 38     65.2
# 29     66.3
# 170    65.6
# 190    64.0
# 33     64.0
# 136    66.5
# 145    65.4
# 173    66.5
# 31     63.9
# 11     64.8
# 119    63.8
# 169    65.6
# 34     64.0
# 84     66.3
# 184    65.5
# 120    63.8
# 35     64.0
#        ...
# 14     66.9
# 162    64.4
# 59     66.5
# 19     63.6
# 177    66.5
# 39     65.2
# 110    68.4
# 164    64.0
# 56     65.7
# 176    66.5
# 124    66.3
# 181    66.5
# 154    63.6
# 53     64.2
# 94     63.8
# 143    65.4
# 105    67.9
# 132    66.5
# 42     66.0
# 17     70.9
# 5      66.3
# 150    63.6
# 199    67.2
# 48     69.6
# 165    64.0
# 66     66.1
# 114    68.4
# 54     64.2
# 93     63.8
# 122    63.8
# Name: carwidth, Length: 82, dtype: float64

# %%
y_train
# Out:
# 89      5499.0
# 171    11549.0
# 123     8921.0
# 12     20970.0
# 127    34028.0
# 102    14399.0
# 196    15985.0
# 159     7788.0
# 99      8949.0
# 81      8499.0
# 188     9995.0
# 194    12940.0
# 13     21105.0
# 82     12629.0
# 179    15998.0
# 183     7975.0
# 45      8916.5
# 108    13200.0
# 36      7295.0
# 166     9538.0
# 191    13295.0
# 158     7898.0
# 112    16900.0
# 153     6918.0
# 202    21485.0
# 118     5572.0
# 198    18420.0
# 75     16503.0
# 21      5572.0
# 91      6649.0
#         ...
# 22      6377.0
# 61     10595.0
# 63     10795.0
# 7      18920.0
# 201    19045.0
# 141     7126.0
# 86      8189.0
# 96      7499.0
# 68     28248.0
# 50      5195.0
# 142     7775.0
# 157     7198.0
# 156     6938.0
# 139     7053.0
# 146     7463.0
# 101    13499.0
# 20      6575.0
# 178    16558.0
# 25      6692.0
# 134    15040.0
# 71     34184.0
# 129    31400.5
# 144     9233.0
# 192    13845.0
# 79      7689.0
# 133    12170.0
# 137    18620.0
# 72     35056.0
# ...

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
#         ...
# 14     24565.0
# 162     9258.0
# 59      8845.0
# 19      6295.0
# 177    11248.0
# 39      8845.0
# 110    13860.0
# 164     8238.0
# 56     11845.0
# 176    10898.0
# 124    12764.0
# 181    15750.0
# 154     7898.0
# 53      6695.0
# 94      7299.0
# 143     9960.0
# 105    19699.0
# 132    11850.0
# 42     10345.0
# 17     36880.0
# 5      15250.0
# 150     5348.0
# 199    18950.0
# 48     35550.0
# 165     9298.0
# 66     18344.0
# 114    17075.0
# 54      7395.0
# ...

# %%
X_train=X_train.values.reshape((-1,1))

# %%
X_train
# Out:
# array([[63.8],
#        [65.6],
#        [64.6],
#        [64.8],
#        [65. ],
#        [66.5],
#        [67.2],
#        [64.4],
#        [65.2],
#        [65.4],
#        [65.5],
#        [67.2],
#        [64.8],
#        [66.3],
#        [67.7],
#        [65.5],
#        [63.6],
#        [68.4],
#        [63.9],
#        [64. ],
#        [66.9],
#        [64.4],
#        [68.4],
#        [63.6],
#        [68.9],
#        [63.8],
#        [67.2],
#        [68. ],
#        [63.8],
#        [63.8],
#        [65.5],
#        [65.5],
#        [71.7],
#        [65.4],
#        [63.6],
#        [71.4],
#        [65.6],
#        [64.1],
#        [64.4],
#        [64.4],
#        [68.4],
#        [66.1],
#        [65.7],
#        [68.9],
#        [65.4],
#        [64.2],
#        [65.2],
#        [72. ],
#        [63.8],
#        [65.4],
#        [65.4],
#        [68.9],
#        [64.8],
#        [64. ],
#        [66.3],
#        [64.4],
#        [65.2],
#        [68.3],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy=model.score(X_train,y_train)
print("Accuracy of the model:",accuracy)
# Out:
# Accuracy of the model: 0.5094503287304999

# %%
#print coefficients
print("intercept:",model.intercept_)
print("slope:",model.coef_)
# Out:
# intercept: -159293.74869696744
# slope: [2615.71910008]

# %%
X_test=X_test.values.reshape((-1,1))

# %%
X_test
# Out:
# array([[64.4],
#        [63.8],
#        [63.6],
#        [63.6],
#        [62.5],
#        [70.3],
#        [63.8],
#        [60.3],
#        [63.6],
#        [66.5],
#        [66.4],
#        [65.6],
#        [67.2],
#        [65.2],
#        [66.3],
#        [65.6],
#        [64. ],
#        [64. ],
#        [66.5],
#        [65.4],
#        [66.5],
#        [63.9],
#        [64.8],
#        [63.8],
#        [65.6],
#        [64. ],
#        [66.3],
#        [65.5],
#        [63.8],
#        [64. ],
#        [64. ],
#        [64.6],
#        [67.9],
#        [66.5],
#        [68.4],
#        [65.5],
#        [63.8],
#        [69.6],
#        [65.7],
#        [68.9],
#        [63.4],
#        [67.9],
#        [63.8],
#        [65.4],
#        [65.5],
#        [63.8],
#        [71.7],
#        [64.2],
#        [68.3],
#        [66.5],
#        [70.3],
#        [68.4],
#        [66.9],
#        [64.4],
#        [66.5],
#        [63.6],
#        [66.5],
#        [65.2],
# ...

# %%
#predictions from the model
predictions=model.predict(X_test)
print("predicted price:",predictions,sep = '\n')
# Out:
# predicted price:
# [ 9158.56134848  7589.12988843  7065.98606841  7065.98606841
#   4188.69505832 24591.30403898  7589.12988843 -1565.88696187
#   7065.98606841 14651.57145866 14389.99954865 12297.42426858
#  16482.57482871 11251.13662855 14128.42763864 12297.42426858
#   8112.27370844  8112.27370844 14651.57145866 11774.28044856
#  14651.57145866  7850.70179844 10204.84898851  7589.12988843
#  12297.42426858  8112.27370844 14128.42763864 12035.85235857
#   7589.12988843  8112.27370844  8112.27370844  9681.7051685
#  18313.57819877 14651.57145866 19621.43774882 12035.85235857
#   7589.12988843 22760.30066892 12558.99617859 20929.29729886
#   6542.84224839 18313.57819877  7589.12988843 11774.28044856
#  12035.85235857  7589.12988843 28253.3107791   8635.41752846
#  19359.86583881 14651.57145866 24591.30403898 19621.43774882
#  15697.85909869  9158.56134848 14651.57145866  7065.98606841
#  14651.57145866 11251.13662855 19621.43774882  8112.27370844
# ...

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train = X_train.reshape(-1,1)
y_train_prediction = model.predict(X_train)
X_test = X_test.reshape(-1,1)
y_test_prediction = model.predict(X_test)

# %%
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training = r2_score(y_train,y_train_prediction)
print('The model performance for training set')
print('-------------------------------------')
print('RMSE is {}'.format(rmse_training))
print('R2_score is {}'.format(r2_training))
# Out:
# The model performance for training set
# -------------------------------------
# RMSE is 5562.28014757713
# R2_score is 0.5094503287304999

# %%
rmse_testing = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing = r2_score(y_test,y_test_prediction)
print('The model performance for testing set')
print('-------------------------------------')
print('root mean squared error is:',rmse_testing)
print('r2 score is:',r2_testing)
# Out:
# The model performance for testing set
# -------------------------------------
# root mean squared error is: 4627.304443979513
# r2 score is: 0.6655241531017995

# %%
# plotting values
#data points
plt.scatter(X,y)
plt.xlabel('carwidth')
plt.ylabel('price')
# Out:
# Text(0,0.5,'price')

# %%
X = X.values.reshape(-1,1)
y_predicted = model.predict(X)
#predicted values
plt.plot(X,y_predicted,color = 'r')
plt.show()

# %% [markdown]
# # curbweight-price

# %%
X=car_prices['curbweight']
y=car_prices['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
# 89     1889
# 171    2714
# 123    2535
# 12     2710
# 127    2756
# 102    3296
# 196    2935
# 159    2275
# 99     2324
# 81     2328
# 188    2300
# 194    2912
# 13     2765
# 82     2833
# 179    3016
# 183    2209
# 45     1909
# 108    3197
# 36     2024
# 166    2300
# 191    2661
# 158    2275
# 112    3252
# 153    2280
# 202    3012
# 118    1918
# 198    3045
# 75     2910
# 21     1876
# 91     1918
#        ...
# 22     1876
# 61     2385
# 63     2443
# 7      2954
# 201    3049
# 141    2145
# 86     2405
# 96     1971
# 68     3750
# 50     1890
# 142    2190
# 157    2109
# 156    2081
# 139    2120
# 146    2290
# 101    3095
# 20     1909
# 178    2976
# 25     1989
# 134    2707
# 71     3740
# 129    3366
# 144    2385
# 192    2579
# 79     2145
# 133    2695
# 137    2847
# 72     3685
# 140    2240
# 37     2236
# Name: curbweight, Length: 123, dtype: int64

# %%
X_test
# Out:
# 78     2004
# 97     2037
# 151    2040
# 44     1874
# 40     2372
# 67     3515
# 98     2008
# 18     1488
# 152    2015
# 62     2410
# 4      2824
# 172    2975
# 197    3042
# 38     2289
# 29     2811
# 170    2679
# 190    2221
# 33     1940
# 136    2808
# 145    2510
# 173    2326
# 31     1819
# 11     2395
# 119    2128
# 169    2551
# 34     1956
# 84     2926
# 184    2264
# 120    1967
# 35     2010
#        ...
# 14     3055
# 162    2140
# 59     2385
# 19     1874
# 177    2458
# 39     2304
# 110    3430
# 164    2204
# 56     2380
# 176    2414
# 124    2818
# 181    3151
# 154    2290
# 53     1945
# 94     1951
# 143    2340
# 105    3139
# 132    2658
# 42     2293
# 17     3505
# 5      2507
# 150    1985
# 199    3157
# 48     4066
# 165    2265
# 66     2700
# 114    3485
# 54     1950
# 93     2024
# 122    2191
# Name: curbweight, Length: 82, dtype: int64

# %%
y_train
# Out:
# 89      5499.0
# 171    11549.0
# 123     8921.0
# 12     20970.0
# 127    34028.0
# 102    14399.0
# 196    15985.0
# 159     7788.0
# 99      8949.0
# 81      8499.0
# 188     9995.0
# 194    12940.0
# 13     21105.0
# 82     12629.0
# 179    15998.0
# 183     7975.0
# 45      8916.5
# 108    13200.0
# 36      7295.0
# 166     9538.0
# 191    13295.0
# 158     7898.0
# 112    16900.0
# 153     6918.0
# 202    21485.0
# 118     5572.0
# 198    18420.0
# 75     16503.0
# 21      5572.0
# 91      6649.0
#         ...
# 22      6377.0
# 61     10595.0
# 63     10795.0
# 7      18920.0
# 201    19045.0
# 141     7126.0
# 86      8189.0
# 96      7499.0
# 68     28248.0
# 50      5195.0
# 142     7775.0
# 157     7198.0
# 156     6938.0
# 139     7053.0
# 146     7463.0
# 101    13499.0
# 20      6575.0
# 178    16558.0
# 25      6692.0
# 134    15040.0
# 71     34184.0
# 129    31400.5
# 144     9233.0
# 192    13845.0
# 79      7689.0
# 133    12170.0
# 137    18620.0
# 72     35056.0
# ...

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
#         ...
# 14     24565.0
# 162     9258.0
# 59      8845.0
# 19      6295.0
# 177    11248.0
# 39      8845.0
# 110    13860.0
# 164     8238.0
# 56     11845.0
# 176    10898.0
# 124    12764.0
# 181    15750.0
# 154     7898.0
# 53      6695.0
# 94      7299.0
# 143     9960.0
# 105    19699.0
# 132    11850.0
# 42     10345.0
# 17     36880.0
# 5      15250.0
# 150     5348.0
# 199    18950.0
# 48     35550.0
# 165     9298.0
# 66     18344.0
# 114    17075.0
# 54      7395.0
# ...

# %%
X_train=X_train.values.reshape((-1,1))

# %%
X_train
# Out:
# array([[1889],
#        [2714],
#        [2535],
#        [2710],
#        [2756],
#        [3296],
#        [2935],
#        [2275],
#        [2324],
#        [2328],
#        [2300],
#        [2912],
#        [2765],
#        [2833],
#        [3016],
#        [2209],
#        [1909],
#        [3197],
#        [2024],
#        [2300],
#        [2661],
#        [2275],
#        [3252],
#        [2280],
#        [3012],
#        [1918],
#        [3045],
#        [2910],
#        [1876],
#        [1918],
#        [2275],
#        [2823],
#        [3770],
#        [2365],
#        [3110],
#        [2844],
#        [2540],
#        [2548],
#        [2094],
#        [1944],
#        [3285],
#        [2670],
#        [2380],
#        [2952],
#        [2403],
#        [2254],
#        [2734],
#        [3715],
#        [1938],
#        [2420],
#        [2403],
#        [3217],
#        [2395],
#        [1837],
#        [2921],
#        [2122],
#        [2302],
#        [2778],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy=model.score(X_train,y_train)
print("Accuracy of the model:",accuracy)
# Out:
# Accuracy of the model: 0.6512059480283948

# %%
#print coefficients
print("intercept:",model.intercept_)
print("slope:",model.coef_)
# Out:
# intercept: -20160.192608256686
# slope: [13.08486082]

# %%
X_test=X_test.values.reshape((-1,1))

# %%
X_test
# Out:
# array([[2004],
#        [2037],
#        [2040],
#        [1874],
#        [2372],
#        [3515],
#        [2008],
#        [1488],
#        [2015],
#        [2410],
#        [2824],
#        [2975],
#        [3042],
#        [2289],
#        [2811],
#        [2679],
#        [2221],
#        [1940],
#        [2808],
#        [2510],
#        [2326],
#        [1819],
#        [2395],
#        [2128],
#        [2551],
#        [1956],
#        [2926],
#        [2264],
#        [1967],
#        [2010],
#        [2169],
#        [2535],
#        [3380],
#        [2579],
#        [3252],
#        [2261],
#        [2191],
#        [4066],
#        [2500],
#        [3062],
#        [2050],
#        [3139],
#        [2017],
#        [2455],
#        [2212],
#        [2028],
#        [3900],
#        [1900],
#        [3130],
#        [3060],
#        [3495],
#        [3020],
#        [3055],
#        [2140],
#        [2385],
#        [1874],
#        [2458],
#        [2304],
# ...

# %%
#predictions from the model
predictions=model.predict(X_test)
print("predicted price:",predictions,sep = '\n')
# Out:
# predicted price:
# [ 6061.86847245  6493.66887946  6532.92346192  4360.83656601
#  10877.09725373 25833.09316953  6114.20791572  -689.91971001
#   6205.80194145 11374.32196485 16791.45434379 18767.26832742
#  19643.95400227  9791.05380578 16621.35115315 14894.14952508
#   8901.28327011  5224.43738005 16582.09657069 12682.80804672
#  10275.19365607  3641.16922099 11178.04905256  7684.39121397
#  13219.28734028  5433.79515315 18126.1101473   9463.93228531
#   5577.72862215  6140.37763736  8220.87050754 13009.92956718
#  24066.636959   13585.66344321 22391.7747742   9424.67770286
#   8508.73744555 33042.85148064 12551.95943853 19905.65121865
#   6663.77207011 20913.18550169  6231.97166309 11963.14070169
#   8783.51952274  6375.9051321  30870.76458473  4701.0429473
#  20795.42175432 19879.48149701 25571.39595315 19356.08706426
#  19814.05719292  7841.40954379 11047.20044438  4360.83656601
#  12002.39528414  9987.32671806 24720.87999993  8678.84063619
# ...

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train = X_train.reshape(-1,1)
y_train_prediction = model.predict(X_train)
X_test = X_test.reshape(-1,1)
y_test_prediction = model.predict(X_test)

# %%
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training = r2_score(y_train,y_train_prediction)
print('The model performance for training set')
print('-------------------------------------')
print('RMSE is {}'.format(rmse_training))
print('R2_score is {}'.format(r2_training))
# Out:
# The model performance for training set
# -------------------------------------
# RMSE is 4690.248996404192
# R2_score is 0.6512059480283949

# %%
rmse_testing = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing = r2_score(y_test,y_test_prediction)
print('The model performance for testing set')
print('-------------------------------------')
print('root mean squared error is:',rmse_testing)
print('r2 score is:',r2_testing)
# Out:
# The model performance for testing set
# -------------------------------------
# root mean squared error is: 3878.611479293492
# r2 score is: 0.7650036206128955

# %%
# plotting values
#data points
plt.scatter(X,y)
plt.xlabel('curbweight')
plt.ylabel('price')
# Out:
# Text(0,0.5,'price')

# %%
X = X.values.reshape(-1,1)
y_predicted = model.predict(X)
#predicted values
plt.plot(X,y_predicted,color = 'r')
plt.show()

# %% [markdown]
# # enginesize-price

# %%
X=car_prices['enginesize']
y=car_prices['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
# 89      97
# 171    146
# 123    122
# 12     164
# 127    194
# 102    181
# 196    141
# 159    110
# 99     120
# 81     122
# 188    109
# 194    141
# 13     164
# 82     156
# 179    171
# 183    109
# 45      90
# 108    152
# 36      92
# 166     98
# 191    136
# 158    110
# 112    152
# 153     92
# 202    173
# 118     90
# 198    130
# 75     140
# 21      90
# 91      97
#       ...
# 22      90
# 61     122
# 63     122
# 7      136
# 201    141
# 141    108
# 86     122
# 96      97
# 68     183
# 50      91
# 142    108
# 157     98
# 156     98
# 139    108
# 146    108
# 101    181
# 20      90
# 178    171
# 25      90
# 134    121
# 71     234
# 129    203
# 144    108
# 192     97
# 79      98
# 133    121
# 137    121
# 72     234
# 140    108
# 37     110
# Name: enginesize, Length: 123, dtype: int64

# %%
X_test
# Out:
# 78      92
# 97      97
# 151     92
# 44      90
# 40     110
# 67     183
# 98      97
# 18      61
# 152     92
# 62     122
# 4      136
# 172    146
# 197    141
# 38     110
# 29     156
# 170    146
# 190    109
# 33      92
# 136    121
# 145    108
# 173    122
# 31      92
# 11     108
# 119     98
# 169    146
# 34      92
# 84     156
# 184     97
# 120     90
# 35      92
#       ...
# 14     164
# 162     98
# 59     122
# 19      90
# 177    122
# 39     110
# 110    152
# 164     98
# 56      70
# 176    122
# 124    156
# 181    161
# 154     92
# 53      91
# 94      97
# 143    108
# 105    181
# 132    121
# 42     110
# 17     209
# 5      136
# 150     92
# 199    130
# 48     258
# 165     98
# 66     134
# 114    152
# 54      91
# 93      97
# 122     98
# Name: enginesize, Length: 82, dtype: int64

# %%
y_train
# Out:
# 89      5499.0
# 171    11549.0
# 123     8921.0
# 12     20970.0
# 127    34028.0
# 102    14399.0
# 196    15985.0
# 159     7788.0
# 99      8949.0
# 81      8499.0
# 188     9995.0
# 194    12940.0
# 13     21105.0
# 82     12629.0
# 179    15998.0
# 183     7975.0
# 45      8916.5
# 108    13200.0
# 36      7295.0
# 166     9538.0
# 191    13295.0
# 158     7898.0
# 112    16900.0
# 153     6918.0
# 202    21485.0
# 118     5572.0
# 198    18420.0
# 75     16503.0
# 21      5572.0
# 91      6649.0
#         ...
# 22      6377.0
# 61     10595.0
# 63     10795.0
# 7      18920.0
# 201    19045.0
# 141     7126.0
# 86      8189.0
# 96      7499.0
# 68     28248.0
# 50      5195.0
# 142     7775.0
# 157     7198.0
# 156     6938.0
# 139     7053.0
# 146     7463.0
# 101    13499.0
# 20      6575.0
# 178    16558.0
# 25      6692.0
# 134    15040.0
# 71     34184.0
# 129    31400.5
# 144     9233.0
# 192    13845.0
# 79      7689.0
# 133    12170.0
# 137    18620.0
# 72     35056.0
# ...

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
#         ...
# 14     24565.0
# 162     9258.0
# 59      8845.0
# 19      6295.0
# 177    11248.0
# 39      8845.0
# 110    13860.0
# 164     8238.0
# 56     11845.0
# 176    10898.0
# 124    12764.0
# 181    15750.0
# 154     7898.0
# 53      6695.0
# 94      7299.0
# 143     9960.0
# 105    19699.0
# 132    11850.0
# 42     10345.0
# 17     36880.0
# 5      15250.0
# 150     5348.0
# 199    18950.0
# 48     35550.0
# 165     9298.0
# 66     18344.0
# 114    17075.0
# 54      7395.0
# ...

# %%
X_train=X_train.values.reshape((-1,1))

# %%
X_train
# Out:
# array([[ 97],
#        [146],
#        [122],
#        [164],
#        [194],
#        [181],
#        [141],
#        [110],
#        [120],
#        [122],
#        [109],
#        [141],
#        [164],
#        [156],
#        [171],
#        [109],
#        [ 90],
#        [152],
#        [ 92],
#        [ 98],
#        [136],
#        [110],
#        [152],
#        [ 92],
#        [173],
#        [ 90],
#        [130],
#        [140],
#        [ 90],
#        [ 97],
#        [109],
#        [152],
#        [183],
#        [122],
#        [ 92],
#        [136],
#        [146],
#        [130],
#        [ 98],
#        [ 92],
#        [120],
#        [140],
#        [ 70],
#        [141],
#        [110],
#        [109],
#        [119],
#        [304],
#        [ 97],
#        [108],
#        [110],
#        [145],
#        [108],
#        [ 79],
#        [156],
#        [ 98],
#        [120],
#        [151],
#        [ 98],
#        [194],
#        [131],
#        [122],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy=model.score(X_train,y_train)
print("Accuracy of the model:",accuracy)
# Out:
# Accuracy of the model: 0.750270883988127

# %%
#print coefficients
print("intercept:",model.intercept_)
print("slope:",model.coef_)
# Out:
# intercept: -8202.088134201436
# slope: [169.18568848]

# %%
X_test=X_test.values.reshape((-1,1))

# %%
X_test
# Out:
# array([[ 92],
#        [ 97],
#        [ 92],
#        [ 90],
#        [110],
#        [183],
#        [ 97],
#        [ 61],
#        [ 92],
#        [122],
#        [136],
#        [146],
#        [141],
#        [110],
#        [156],
#        [146],
#        [109],
#        [ 92],
#        [121],
#        [108],
#        [122],
#        [ 92],
#        [108],
#        [ 98],
#        [146],
#        [ 92],
#        [156],
#        [ 97],
#        [ 90],
#        [ 92],
#        [ 98],
#        [122],
#        [209],
#        [132],
#        [152],
#        [ 97],
#        [ 98],
#        [258],
#        [ 80],
#        [141],
#        [ 97],
#        [181],
#        [103],
#        [108],
#        [109],
#        [ 97],
#        [308],
#        [ 91],
#        [134],
#        [181],
#        [183],
#        [120],
#        [164],
#        [ 98],
#        [122],
#        [ 90],
#        [122],
#        [110],
#        [152],
#        [ 98],
#        [ 70],
#        [122],
# ...

# %%
#predictions from the model
predictions=model.predict(X_test)
print("predicted price:",predictions,sep = '\n')
# Out:
# predicted price:
# [ 7362.99520594  8208.92364834  7362.99520594  7024.62382898
#  10408.33759857 22758.8928576   8208.92364834  2118.23886307
#   7362.99520594 12438.56586033 14807.16549905 16499.02238385
#  15653.09394145 10408.33759857 18190.87926864 16499.02238385
#  10239.15191009  7362.99520594 12269.38017185 10069.96622161
#  12438.56586033  7362.99520594 10069.96622161  8378.10933682
#  16499.02238385  7362.99520594 18190.87926864  8208.92364834
#   7024.62382898  7362.99520594  8378.10933682 12438.56586033
#  27157.72075807 14130.42274513 17514.13651473  8208.92364834
#   8378.10933682 35447.81949358  5332.76694418 15653.09394145
#   8208.92364834 22420.52148064  9224.03777922 10069.96622161
#  10239.15191009  8208.92364834 43907.10391757  7193.80951746
#  14468.79412209 22420.52148064 22758.8928576  12100.19448337
#  19544.36477648  8378.10933682 12438.56586033  7024.62382898
#  12438.56586033 10408.33759857 17514.13651473  8378.10933682
# ...

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train = X_train.reshape(-1,1)
y_train_prediction = model.predict(X_train)
X_test = X_test.reshape(-1,1)
y_test_prediction = model.predict(X_test)

# %%
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training = r2_score(y_train,y_train_prediction)
print('The model performance for training set')
print('-------------------------------------')
print('RMSE is {}'.format(rmse_training))
print('R2_score is {}'.format(r2_training))
# Out:
# The model performance for training set
# -------------------------------------
# RMSE is 3968.6788251156663
# R2_score is 0.7502708839881269

# %%
rmse_testing = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing = r2_score(y_test,y_test_prediction)
print('The model performance for testing set')
print('-------------------------------------')
print('root mean squared error is:',rmse_testing)
print('r2 score is:',r2_testing)
# Out:
# The model performance for testing set
# -------------------------------------
# root mean squared error is: 3719.5073286893535
# r2 score is: 0.7838877167904686

# %%
# plotting values
#data points
plt.scatter(X,y)
plt.xlabel('enginesize')
plt.ylabel('price')
# Out:
# Text(0,0.5,'price')

# %%
X = X.values.reshape(-1,1)
y_predicted = model.predict(X)
#predicted values
plt.plot(X,y_predicted,color = 'r')
plt.show()

# %% [markdown]
# # boreratio-price

# %%
X=car_prices['boreratio']
y=car_prices['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
# 89     3.15
# 171    3.62
# 123    3.35
# 12     3.31
# 127    3.74
# 102    3.43
# 196    3.78
# 159    3.27
# 99     3.33
# 81     3.35
# 188    3.19
# 194    3.78
# 13     3.31
# 82     3.58
# 179    3.27
# 183    3.19
# 45     3.03
# 108    3.70
# 36     2.92
# 166    3.24
# 191    3.19
# 158    3.27
# 112    3.70
# 153    3.05
# 202    3.58
# 118    2.97
# 198    3.62
# 75     3.78
# 21     2.97
# 91     3.15
#        ...
# 22     2.97
# 61     3.39
# 63     3.39
# 7      3.19
# 201    3.78
# 141    3.62
# 86     3.35
# 96     3.15
# 68     3.58
# 50     3.03
# 142    3.62
# 157    3.19
# 156    3.19
# 139    3.62
# 146    3.62
# 101    3.43
# 20     3.03
# 178    3.27
# 25     2.97
# 134    2.54
# 71     3.46
# 129    3.94
# 144    3.62
# 192    3.01
# 79     3.03
# 133    3.54
# 137    3.54
# 72     3.46
# 140    3.62
# 37     3.15
# Name: boreratio, Length: 123, dtype: float64

# %%
X_test
# Out:
# 78     2.97
# 97     3.15
# 151    3.05
# 44     3.03
# 40     3.15
# 67     3.58
# 98     3.15
# 18     2.91
# 152    3.05
# 62     3.39
# 4      3.19
# 172    3.62
# 197    3.78
# 38     3.15
# 29     3.60
# 170    3.62
# 190    3.19
# 33     2.91
# 136    3.54
# 145    3.62
# 173    3.31
# 31     2.91
# 11     3.50
# 119    3.03
# 169    3.62
# 34     2.91
# 84     3.59
# 184    3.01
# 120    2.97
# 35     2.91
#        ...
# 14     3.31
# 162    3.19
# 59     3.39
# 19     3.03
# 177    3.31
# 39     3.15
# 110    3.70
# 164    3.19
# 56     3.33
# 176    3.31
# 124    3.59
# 181    3.27
# 154    3.05
# 53     3.03
# 94     3.15
# 143    3.62
# 105    3.43
# 132    3.54
# 42     3.15
# 17     3.62
# 5      3.19
# 150    3.05
# 199    3.62
# 48     3.63
# 165    3.24
# 66     3.43
# 114    3.70
# 54     3.08
# 93     3.15
# 122    2.97
# Name: boreratio, Length: 82, dtype: float64

# %%
y_train
# Out:
# 89      5499.0
# 171    11549.0
# 123     8921.0
# 12     20970.0
# 127    34028.0
# 102    14399.0
# 196    15985.0
# 159     7788.0
# 99      8949.0
# 81      8499.0
# 188     9995.0
# 194    12940.0
# 13     21105.0
# 82     12629.0
# 179    15998.0
# 183     7975.0
# 45      8916.5
# 108    13200.0
# 36      7295.0
# 166     9538.0
# 191    13295.0
# 158     7898.0
# 112    16900.0
# 153     6918.0
# 202    21485.0
# 118     5572.0
# 198    18420.0
# 75     16503.0
# 21      5572.0
# 91      6649.0
#         ...
# 22      6377.0
# 61     10595.0
# 63     10795.0
# 7      18920.0
# 201    19045.0
# 141     7126.0
# 86      8189.0
# 96      7499.0
# 68     28248.0
# 50      5195.0
# 142     7775.0
# 157     7198.0
# 156     6938.0
# 139     7053.0
# 146     7463.0
# 101    13499.0
# 20      6575.0
# 178    16558.0
# 25      6692.0
# 134    15040.0
# 71     34184.0
# 129    31400.5
# 144     9233.0
# 192    13845.0
# 79      7689.0
# 133    12170.0
# 137    18620.0
# 72     35056.0
# ...

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
#         ...
# 14     24565.0
# 162     9258.0
# 59      8845.0
# 19      6295.0
# 177    11248.0
# 39      8845.0
# 110    13860.0
# 164     8238.0
# 56     11845.0
# 176    10898.0
# 124    12764.0
# 181    15750.0
# 154     7898.0
# 53      6695.0
# 94      7299.0
# 143     9960.0
# 105    19699.0
# 132    11850.0
# 42     10345.0
# 17     36880.0
# 5      15250.0
# 150     5348.0
# 199    18950.0
# 48     35550.0
# 165     9298.0
# 66     18344.0
# 114    17075.0
# 54      7395.0
# ...

# %%
X_train=X_train.values.reshape((-1,1))

# %%
X_train
# Out:
# array([[3.15],
#        [3.62],
#        [3.35],
#        [3.31],
#        [3.74],
#        [3.43],
#        [3.78],
#        [3.27],
#        [3.33],
#        [3.35],
#        [3.19],
#        [3.78],
#        [3.31],
#        [3.58],
#        [3.27],
#        [3.19],
#        [3.03],
#        [3.7 ],
#        [2.92],
#        [3.24],
#        [3.19],
#        [3.27],
#        [3.7 ],
#        [3.05],
#        [3.58],
#        [2.97],
#        [3.62],
#        [3.78],
#        [2.97],
#        [3.15],
#        [3.19],
#        [2.68],
#        [3.58],
#        [3.35],
#        [3.05],
#        [3.19],
#        [3.62],
#        [3.47],
#        [3.19],
#        [2.97],
#        [3.46],
#        [3.76],
#        [3.33],
#        [3.78],
#        [3.17],
#        [3.19],
#        [3.43],
#        [3.8 ],
#        [3.15],
#        [3.62],
#        [3.17],
#        [3.01],
#        [3.5 ],
#        [2.91],
#        [3.59],
#        [3.19],
#        [3.33],
#        [3.94],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy=model.score(X_train,y_train)
print("Accuracy of the model:",accuracy)
# Out:
# Accuracy of the model: 0.2394927344299772

# %%
#print coefficients
print("intercept:",model.intercept_)
print("slope:",model.coef_)
# Out:
# intercept: -33629.574257005246
# slope: [14106.32422186]

# %%
X_test=X_test.values.reshape((-1,1))

# %%
X_test
# Out:
# array([[2.97],
#        [3.15],
#        [3.05],
#        [3.03],
#        [3.15],
#        [3.58],
#        [3.15],
#        [2.91],
#        [3.05],
#        [3.39],
#        [3.19],
#        [3.62],
#        [3.78],
#        [3.15],
#        [3.6 ],
#        [3.62],
#        [3.19],
#        [2.91],
#        [3.54],
#        [3.62],
#        [3.31],
#        [2.91],
#        [3.5 ],
#        [3.03],
#        [3.62],
#        [2.91],
#        [3.59],
#        [3.01],
#        [2.97],
#        [2.91],
#        [3.19],
#        [3.34],
#        [3.62],
#        [3.46],
#        [3.7 ],
#        [3.01],
#        [3.03],
#        [3.63],
#        [3.33],
#        [3.78],
#        [3.62],
#        [3.43],
#        [2.99],
#        [3.62],
#        [3.19],
#        [3.15],
#        [3.8 ],
#        [3.03],
#        [3.61],
#        [3.43],
#        [3.58],
#        [3.46],
#        [3.31],
#        [3.19],
#        [3.39],
#        [3.03],
#        [3.31],
#        [3.15],
# ...

# %%
#predictions from the model
predictions=model.predict(X_test)
print("predicted price:",predictions,sep = '\n')
# Out:
# predicted price:
# [ 8266.20868191 10805.34704184  9394.71461965  9112.58813522
#  10805.34704184 16871.06645724 10805.34704184  7419.82922859
#   9394.71461965 14190.86485509 11369.60001071 17435.31942611
#  19692.33130161 10805.34704184 17153.19294168 17435.31942611
#  11369.60001071  7419.82922859 16306.81348836 17435.31942611
#  13062.35891734  7419.82922859 15742.56051949  9112.58813522
#  17435.31942611  7419.82922859 17012.12969946  8830.46165078
#   8266.20868191  7419.82922859 11369.60001071 13485.54864399
#  17435.31942611 15178.30755062 18563.82536386  8830.46165078
#   9112.58813522 17576.38266833 13344.48540177 19692.33130161
#  17435.31942611 14755.11782396  8548.33516634 17435.31942611
#  11369.60001071 10805.34704184 19974.45778605  9112.58813522
#  17294.25618389 14755.11782396 16871.06645724 15178.30755062
#  13062.35891734 11369.60001071 14190.86485509  9112.58813522
#  13062.35891734 10805.34704184 18563.82536386 11369.60001071
# ...

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train = X_train.reshape(-1,1)
y_train_prediction = model.predict(X_train)
X_test = X_test.reshape(-1,1)
y_test_prediction = model.predict(X_test)

# %%
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training = r2_score(y_train,y_train_prediction)
print('The model performance for training set')
print('-------------------------------------')
print('RMSE is {}'.format(rmse_training))
print('R2_score is {}'.format(r2_training))
# Out:
# The model performance for training set
# -------------------------------------
# RMSE is 6925.689993104315
# R2_score is 0.2394927344299772

# %%
rmse_testing = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing = r2_score(y_test,y_test_prediction)
print('The model performance for testing set')
print('-------------------------------------')
print('root mean squared error is:',rmse_testing)
print('r2 score is:',r2_testing)
# Out:
# The model performance for testing set
# -------------------------------------
# root mean squared error is: 6256.560249664315
# r2 score is: 0.3885233517596596

# %%
# plotting values
#data points
plt.scatter(X,y)
plt.xlabel('boreratio')
plt.ylabel('price')
# Out:
# Text(0,0.5,'price')

# %%
X = X.values.reshape(-1,1)
y_predicted = model.predict(X)
#predicted values
plt.plot(X,y_predicted,color = 'r')
plt.show()

# %% [markdown]
# # horsepower-price

# %%
X=car_prices['horsepower']
y=car_prices['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
# 89      69
# 171    116
# 123     88
# 12     121
# 127    207
# 102    152
# 196    114
# 159     56
# 99      97
# 81      88
# 188    100
# 194    114
# 13     121
# 82     145
# 179    161
# 183     85
# 45      70
# 108     95
# 36      76
# 166    112
# 191    110
# 158     56
# 112     95
# 153     62
# 202    134
# 118     68
# 198    162
# 75     175
# 21      68
# 91      69
#       ...
# 22      68
# 61      84
# 63      64
# 7      110
# 201    160
# 141     82
# 86      88
# 96      69
# 68     123
# 50      68
# 142     82
# 157     70
# 156     70
# 139     73
# 146     82
# 101    152
# 20      70
# 178    161
# 25      68
# 134    110
# 71     155
# 129    288
# 144     82
# 192     68
# 79     102
# 133    110
# 137    160
# 72     155
# 140     73
# 37      86
# Name: horsepower, Length: 123, dtype: int64

# %%
X_test
# Out:
# 78      68
# 97      69
# 151     62
# 44      70
# 40      86
# 67     123
# 98      69
# 18      48
# 152     62
# 62      84
# 4      115
# 172    116
# 197    114
# 38      86
# 29     145
# 170    116
# 190     90
# 33      76
# 136    160
# 145    111
# 173     92
# 31      76
# 11     101
# 119    102
# 169    116
# 34      76
# 84     145
# 184     52
# 120     68
# 35      76
#       ...
# 14     121
# 162     70
# 59      84
# 19      70
# 177     92
# 39      86
# 110     95
# 164     70
# 56     101
# 176     92
# 124    145
# 181    156
# 154     62
# 53      68
# 94      69
# 143     94
# 105    200
# 132    110
# 42     100
# 17     182
# 5      110
# 150     62
# 199    162
# 48     176
# 165    112
# 66      72
# 114     95
# 54      68
# 93      69
# 122     68
# Name: horsepower, Length: 82, dtype: int64

# %%
y_train
# Out:
# 89      5499.0
# 171    11549.0
# 123     8921.0
# 12     20970.0
# 127    34028.0
# 102    14399.0
# 196    15985.0
# 159     7788.0
# 99      8949.0
# 81      8499.0
# 188     9995.0
# 194    12940.0
# 13     21105.0
# 82     12629.0
# 179    15998.0
# 183     7975.0
# 45      8916.5
# 108    13200.0
# 36      7295.0
# 166     9538.0
# 191    13295.0
# 158     7898.0
# 112    16900.0
# 153     6918.0
# 202    21485.0
# 118     5572.0
# 198    18420.0
# 75     16503.0
# 21      5572.0
# 91      6649.0
#         ...
# 22      6377.0
# 61     10595.0
# 63     10795.0
# 7      18920.0
# 201    19045.0
# 141     7126.0
# 86      8189.0
# 96      7499.0
# 68     28248.0
# 50      5195.0
# 142     7775.0
# 157     7198.0
# 156     6938.0
# 139     7053.0
# 146     7463.0
# 101    13499.0
# 20      6575.0
# 178    16558.0
# 25      6692.0
# 134    15040.0
# 71     34184.0
# 129    31400.5
# 144     9233.0
# 192    13845.0
# 79      7689.0
# 133    12170.0
# 137    18620.0
# 72     35056.0
# ...

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
#         ...
# 14     24565.0
# 162     9258.0
# 59      8845.0
# 19      6295.0
# 177    11248.0
# 39      8845.0
# 110    13860.0
# 164     8238.0
# 56     11845.0
# 176    10898.0
# 124    12764.0
# 181    15750.0
# 154     7898.0
# 53      6695.0
# 94      7299.0
# 143     9960.0
# 105    19699.0
# 132    11850.0
# 42     10345.0
# 17     36880.0
# 5      15250.0
# 150     5348.0
# 199    18950.0
# 48     35550.0
# 165     9298.0
# 66     18344.0
# 114    17075.0
# 54      7395.0
# ...

# %%
X_train=X_train.values.reshape((-1,1))

# %%
X_train
# Out:
# array([[ 69],
#        [116],
#        [ 88],
#        [121],
#        [207],
#        [152],
#        [114],
#        [ 56],
#        [ 97],
#        [ 88],
#        [100],
#        [114],
#        [121],
#        [145],
#        [161],
#        [ 85],
#        [ 70],
#        [ 95],
#        [ 76],
#        [112],
#        [110],
#        [ 56],
#        [ 95],
#        [ 62],
#        [134],
#        [ 68],
#        [162],
#        [175],
#        [ 68],
#        [ 69],
#        [ 85],
#        [154],
#        [123],
#        [ 88],
#        [ 62],
#        [110],
#        [116],
#        [111],
#        [ 70],
#        [ 68],
#        [ 95],
#        [120],
#        [101],
#        [114],
#        [116],
#        [ 90],
#        [ 90],
#        [184],
#        [ 69],
#        [ 82],
#        [116],
#        [106],
#        [101],
#        [ 60],
#        [145],
#        [ 70],
#        [ 97],
#        [143],
#        [102],
#        [207],
#        [160],
#        [ 92],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy=model.score(X_train,y_train)
print("Accuracy of the model:",accuracy)
# Out:
# Accuracy of the model: 0.6622681642120359

# %%
#print coefficients
print("intercept:",model.intercept_)
print("slope:",model.coef_)
# Out:
# intercept: -3219.7909599380146
# slope: [156.71408065]

# %%
X_test=X_test.values.reshape((-1,1))

# %%
X_test
# Out:
# array([[ 68],
#        [ 69],
#        [ 62],
#        [ 70],
#        [ 86],
#        [123],
#        [ 69],
#        [ 48],
#        [ 62],
#        [ 84],
#        [115],
#        [116],
#        [114],
#        [ 86],
#        [145],
#        [116],
#        [ 90],
#        [ 76],
#        [160],
#        [111],
#        [ 92],
#        [ 76],
#        [101],
#        [102],
#        [116],
#        [ 76],
#        [145],
#        [ 52],
#        [ 68],
#        [ 76],
#        [ 70],
#        [ 88],
#        [182],
#        [ 90],
#        [ 95],
#        [ 52],
#        [102],
#        [176],
#        [135],
#        [114],
#        [ 69],
#        [160],
#        [ 55],
#        [ 94],
#        [ 85],
#        [ 69],
#        [184],
#        [ 68],
#        [142],
#        [152],
#        [123],
#        [ 97],
#        [121],
#        [ 70],
#        [ 84],
#        [ 70],
#        [ 92],
#        [ 86],
#        [ 95],
#        [ 70],
#        [101],
#        [ 92],
# ...

# %%
#predictions from the model
predictions=model.predict(X_test)
print("predicted price:",predictions,sep = '\n')
# Out:
# predicted price:
# [ 7436.76652422  7593.48060487  6496.48204033  7750.19468552
#  10257.61997591 16056.04095994  7593.48060487  4302.48491124
#   6496.48204033  9944.19181462 14802.32831475 14959.0423954
#  14645.6142341  10257.61997591 19503.75073423 14959.0423954
#  10884.47629851  8690.47916942 21854.46194397 14175.47199215
#  11197.90445981  8690.47916942 12608.33118566 12765.04526631
#  14959.0423954   8690.47916942 19503.75073423  4929.34123383
#   7436.76652422  8690.47916942  7750.19468552 10571.04813721
#  25302.17171826 10884.47629851 11668.04670176  4929.34123383
#  12765.04526631 24361.88723437 17936.60992774 14645.6142341
#   7593.48060487 21854.46194397  5399.48347578 11511.33262111
#  10100.90589527  7593.48060487 25615.59987956  7436.76652422
#  19033.60849228 20600.74929878 16056.04095994 11981.47486306
#  15742.61279865  7750.19468552  9944.19181462  7750.19468552
#  11197.90445981 10257.61997591 11668.04670176  7750.19468552
# ...

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train = X_train.reshape(-1,1)
y_train_prediction = model.predict(X_train)
X_test = X_test.reshape(-1,1)
y_test_prediction = model.predict(X_test)

# %%
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training = r2_score(y_train,y_train_prediction)
print('The model performance for training set')
print('-------------------------------------')
print('RMSE is {}'.format(rmse_training))
print('R2_score is {}'.format(r2_training))
# Out:
# The model performance for training set
# -------------------------------------
# RMSE is 4615.272672204023
# R2_score is 0.6622681642120359

# %%
rmse_testing = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing = r2_score(y_test,y_test_prediction)
print('The model performance for testing set')
print('-------------------------------------')
print('root mean squared error is:',rmse_testing)
print('r2 score is:',r2_testing)
# Out:
# The model performance for testing set
# -------------------------------------
# root mean squared error is: 4835.071203225254
# r2 score is: 0.6348137961066892

# %%
# plotting values
#data points
plt.scatter(X,y)
plt.xlabel('horsepower')
plt.ylabel('price')
# Out:
# Text(0,0.5,'price')

# %%
X = X.values.reshape(-1,1)
y_predicted = model.predict(X)
#predicted values
plt.plot(X,y_predicted,color = 'r')
plt.show()
